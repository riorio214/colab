# %% [markdown]
# <a href="https://colab.research.google.com/github/riorio214/colab/blob/main/%EC%86%8C%ED%92%88%EC%83%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# 단계 1: 폰트 설치
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
# !apt-get -qq -y install fonts-nanum > /dev/null
#fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'

#font = fm.FontProperties(fname=fontpath, size=9)

#fm._rebuild()



fe = fm.FontEntry(
    fname=r'/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf', # ttf 파일이 저장되어 있는 경로
    name='NanumGothic')                        # 이 폰트의 원하는 이름 설정
fm.fontManager.ttflist.insert(0, fe)              # Matplotlib에 폰트 추가
plt.rcParams.update({'font.size': 18, 'font.family': 'NanumGothic'}) # 폰트 설

# %%
# 단계 2: 런타임 재시작
import os
os.kill(os.getpid(), 9)

# %%
# 단계 3: 한글 폰트 설정
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm

# 마이너스 표시 문제
mpl.rcParams['axes.unicode_minus'] = False

# 한글 폰트 설정
fe = fm.FontEntry(
    fname=r'/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf', # ttf 파일이 저장되어 있는 경로
    name='NanumGothic')                        # 이 폰트의 원하는 이름 설정
fm.fontManager.ttflist.insert(0, fe)              # Matplotlib에 폰트 추가
plt.rcParams.update({'font.size': 18, 'font.family': 'NanumGothic'}) # 폰트 설

# %%
import pandas as pd

df = pd.read_csv('/content/daegu.csv', encoding='cp949')

dataset = df[['상호명','지점명',
              '상권업종대분류코드','상권업종중분류명', '표준산업분류명',
              '시도명', '시군구명', '행정동명',
              '위도', '경도']]

filtered_data = dataset[
    (dataset['상권업종중분류명'].str.contains('오락용품')) &
    (dataset['표준산업분류명'].str.contains('인형')) &
    (dataset['상권업종대분류코드'] == 'G2') &
    (~dataset['상호명'].str.contains('낚시|피싱|루어|레고|프라모델|전자|상사|스포츠|레저|불교|조합|드론'))
]
print(filtered_data)
filtered_data.to_csv('/content/a.csv', index=False, encoding='cp949')
# Out:
# <ipython-input-15-0e49e3502575>:3: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/daegu.csv', encoding='cp949')
#              상호명  지점명 상권업종대분류코드 상권업종중분류명             표준산업분류명    시도명 시군구명  \
# 50           키티영  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  대구광역시   중구
# 1915        죠이레져  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  대구광역시   북구
# 1958      김치빌리아드  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  대구광역시   중구
# 3052      스마일슬라임  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  대구광역시  달성군
# 4073          와드  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  대구광역시   남구
# ...          ...  ...       ...      ...                 ...    ...  ...
# 104034  서재장난감도서관  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  대구광역시  달성군
# 104047  논공장난감도서관  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  대구광역시  달성군
# 104185  다사장난감도서관  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  대구광역시  달성군
# ...

# %%
import pandas as pd

df2 = pd.read_csv('/content/busan.csv', encoding='cp949')

dataset2 = df2[['상호명','지점명',
              '상권업종대분류코드','상권업종중분류명', '표준산업분류명',
              '시도명', '시군구명', '행정동명',
              '위도', '경도']]

# NaN 값을 체크하고 NaN인 경우 False로 채우는 조건 추가
filtered_data = dataset2[
    (dataset2['상권업종중분류명'].str.contains('오락용품')) &
    (dataset2['표준산업분류명'].str.contains('인형')) &
    (dataset2['상권업종대분류코드'] == 'G2') &
    (~dataset2['상호명'].str.contains('낚시|피싱|루어|레고|프라모델|전자|상사|스포츠|레저|불교|조합|드론|고래|바다|어부|강태공|당구', na=False))
]
print(filtered_data)
filtered_data.to_csv('/content/b.csv', index=False, encoding='cp949')
# Out:
# <ipython-input-11-d4cd26e205eb>:3: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('/content/busan.csv', encoding='cp949')
#                      상호명  지점명 상권업종대분류코드 상권업종중분류명             표준산업분류명    시도명  \
# 2781                젤리피코  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  부산광역시
# 6056             삼성출판사롯데  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  부산광역시
# 8677                제이굿즈  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  부산광역시
# 8939               아이빅토이  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  부산광역시
# 10121                 신화  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  부산광역시
# ...                  ...  ...       ...      ...                 ...    ...
# 138754  플레이타임그룹부산온천장점챔피언  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  부산광역시
# 138755    플레이타임그룹삼정타워챔피언  서면점        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  부산광역시
# 140613              동래셔플  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  부산광역시
# ...

# %%
import pandas as pd

df3 = pd.read_csv('/content/seoul.csv', encoding='cp949')

dataset3 = df3[['상호명','지점명',
              '상권업종대분류코드','상권업종중분류명', '표준산업분류명',
              '시도명', '시군구명', '행정동명',
              '위도', '경도']]

# NaN 값을 체크하고 NaN인 경우 False로 채우는 조건 추가
filtered_data = dataset3[
    (dataset3['상권업종중분류명'].str.contains('오락용품')) &
    (dataset3['표준산업분류명'].str.contains('인형')) &
    (dataset3['상권업종대분류코드'] == 'G2') &
    (~dataset3['상호명'].str.contains(
        '낚시|피싱|루어|레고|프라모델|전자|상사|스포츠|레저|불교|조합|드론|고래|바다|어부|강태공|당구|글램핑', na=False))
]
print(filtered_data)
filtered_data.to_csv('/content/c.csv', index=False, encoding='cp949')
# Out:
# <ipython-input-14-9821dfb9eef1>:3: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv('/content/seoul.csv', encoding='cp949')
#                 상호명  지점명 상권업종대분류코드 상권업종중분류명             표준산업분류명    시도명  시군구명  \
# 2884      브라더스인터내셔널  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  서울특별시   강북구
# 4153            파란문  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  서울특별시   광진구
# 4720            보드붐  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  서울특별시   종로구
# 6872          별사탕상점  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  서울특별시  영등포구
# 7528         아이디어플랩  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  서울특별시   종로구
# ...             ...  ...       ...      ...                 ...    ...   ...
# 474765     슬라임238카페  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  서울특별시  동대문구
# 476056      제이에스스토어  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  서울특별시   마포구
# 480746         코코헨나  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  서울특별시   마포구
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium import plugins
df2 = pd.read_csv('/content/b.csv', encoding='cp949')

dataset = df[['상호명','지점명',
              '상권업종대분류코드','상권업종중분류명', '표준산업분류명',
              '시도명', '시군구명', '행정동명',
              '위도', '경도']]

dataset2 = df2[['상호명','지점명',
              '상권업종대분류코드','상권업종중분류명', '표준산업분류명',
              '시도명', '시군구명', '행정동명',
              '위도', '경도']]

dataset3 = df3[['상호명','지점명',
              '상권업종대분류코드','상권업종중분류명', '표준산업분류명',
              '시도명', '시군구명', '행정동명',
              '위도', '경도']]

df.index = range(len(dataset))
print('대구 소품샵 점포 수 :', len(df))
df.head()

df2.index = range(len(dataset2))
print('부산 소품샵 점포 수 :', len(df2))
df2.head()

df3.index = range(len(dataset3))
print('서울 소품샵 점포 수 :', len(df3))
df3.head()
# Out:
# 대구 소품샵 점포 수 : 115
# 부산 소품샵 점포 수 : 126
# 서울 소품샵 점포 수 : 445
#          상호명  지점명 상권업종대분류코드 상권업종중분류명             표준산업분류명    시도명  시군구명  행정동명  \
# 0  브라더스인터내셔널  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  서울특별시   강북구   번1동
# 1        파란문  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  서울특별시   광진구  구의3동
# 2        보드붐  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  서울특별시   종로구   평창동
# 3      별사탕상점  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  서울특별시  영등포구  신길3동
# 4     아이디어플랩  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  서울특별시   종로구   가회동
#
#           위도          경도
# 0  37.637123  127.025168
# 1  37.535713  127.095681
# 2  37.609494  126.961377
# 3  37.509424  126.908372
# 4  37.579811  126.987966

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium import plugins
df2 = pd.read_csv('/content/b.csv', encoding='cp949')

dataset2 = df2[['상호명','지점명',
              '상권업종대분류코드','상권업종중분류명', '표준산업분류명',
              '시도명', '시군구명', '행정동명',
              '위도', '경도']]

df2.index = range(len(dataset2))
print('부산 소품샵 점포 수 :', len(df2))
df2.head()
# Out:
# 부산 소품샵 점포 수 : 126
#        상호명  지점명 상권업종대분류코드 상권업종중분류명             표준산업분류명    시도명  시군구명  행정동명  \
# 0     젤리피코  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  부산광역시  부산진구  범천2동
# 1  삼성출판사롯데  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  부산광역시   동래구  온천2동
# 2     제이굿즈  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  부산광역시  부산진구  부전2동
# 3    아이빅토이  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  부산광역시  해운대구   송정동
# 4       신화  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  부산광역시  부산진구  양정2동
#
#           위도          경도
# 0  35.147530  129.051730
# 1  35.211726  129.077500
# 2  35.153725  129.059789
# 3  35.179713  129.197031
# 4  35.173071  129.075881

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium import plugins
df3 = pd.read_csv('/content/c.csv', encoding='cp949')

dataset3 = df3[['상호명','지점명',
              '상권업종대분류코드','상권업종중분류명', '표준산업분류명',
              '시도명', '시군구명', '행정동명',
              '위도', '경도']]

df3.index = range(len(dataset3))
print('서울 소품샵 점포 수 :', len(df3))
df3.head()
# Out:
# 서울 소품샵 점포 수 : 445
#          상호명  지점명 상권업종대분류코드 상권업종중분류명             표준산업분류명    시도명  시군구명  행정동명  \
# 0  브라더스인터내셔널  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  서울특별시   강북구   번1동
# 1        파란문  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  서울특별시   광진구  구의3동
# 2        보드붐  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  서울특별시   종로구   평창동
# 3      별사탕상점  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  서울특별시  영등포구  신길3동
# 4     아이디어플랩  NaN        G2  오락용품 소매  게임용구, 인형 및 장난감 소매업  서울특별시   종로구   가회동
#
#           위도          경도
# 0  37.637123  127.025168
# 1  37.535713  127.095681
# 2  37.609494  126.961377
# 3  37.509424  126.908372
# 4  37.579811  126.987966

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium import plugins
df = pd.read_csv('/content/a.csv', encoding='cp949')

dataset = df[['상호명','지점명',
              '상권업종대분류코드','상권업종중분류명', '표준산업분류명',
              '시도명', '시군구명', '행정동명',
              '위도', '경도']]

plt.figure(figsize=(8, 4))
sns.scatterplot(x='경도',y='위도', data=dataset, alpha=0.5)
plt.title('위도경도 분포도')
plt.show()

plt.figure(figsize=(20, 4))
sns.countplot(x='시군구명', data=dataset, order=dataset['시군구명'].value_counts().index)
plt.xticks(rotation=90)
plt.title('시군구별 상호 수')
plt.show()
# Out:
# 대구 소품샵 점포 수 : 115

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium import plugins

df = pd.read_csv('/content/a.csv', encoding='cp949')

dataset = df[['상호명','지점명',
              '상권업종대분류코드','상권업종중분류명', '표준산업분류명',
              '시도명', '시군구명', '행정동명',
              '위도', '경도']]

a_map = folium.Map(location=[dataset['위도'].mean(), dataset['경도'].mean()], zoom_start=12)

for index, row in dataset.iterrows():
    folium.Marker(
        location=[row['위도'], row['경도']],
        popup=f"{row['상호명']} - {row['시군구명']}",
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(a_map)

a_map
a_map.save('map1.html')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium import plugins
df = pd.read_csv('/content/b.csv', encoding='cp949')

dataset = df[['상호명','지점명',
              '상권업종대분류코드','상권업종중분류명', '표준산업분류명',
              '시도명', '시군구명', '행정동명',
              '위도', '경도']]


plt.figure(figsize=(8, 4))
sns.scatterplot(x='경도',y='위도', data=dataset, alpha=0.5)
plt.title('위도경도 분포도')
plt.show()

plt.figure(figsize=(20, 4))
sns.countplot(x='시군구명', data=dataset, order=dataset['시군구명'].value_counts().index)
plt.xticks(rotation=90)
plt.title('시군구별 상호 수')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium import plugins

df = pd.read_csv('/content/b.csv', encoding='cp949')

dataset = df[['상호명','지점명',
              '상권업종대분류코드','상권업종중분류명', '표준산업분류명',
              '시도명', '시군구명', '행정동명',
              '위도', '경도']]

b_map = folium.Map(location=[dataset['위도'].mean(), dataset['경도'].mean()], zoom_start=10)

for index, row in dataset.iterrows():
    folium.Marker(
        location=[row['위도'], row['경도']],
        popup=f"{row['상호명']} - {row['시군구명']}",
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(b_map)

b_map
b_map.save('map2.html')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium import plugins
df = pd.read_csv('/content/c.csv', encoding='cp949')

dataset = df[['상호명','지점명',
              '상권업종대분류코드','상권업종중분류명', '표준산업분류명',
              '시도명', '시군구명', '행정동명',
              '위도', '경도']]


plt.figure(figsize=(8, 4))
sns.scatterplot(x='경도',y='위도', data=dataset, alpha=0.5)
plt.title('위도경도 분포도')
plt.show()

plt.figure(figsize=(20, 4))
sns.countplot(x='시군구명', data=dataset, order=dataset['시군구명'].value_counts().index)
plt.xticks(rotation=90)
plt.title('시군구별 상호 수')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from folium import plugins

df = pd.read_csv('/content/c.csv', encoding='cp949')

dataset = df[['상호명','지점명',
              '상권업종대분류코드','상권업종중분류명', '표준산업분류명',
              '시도명', '시군구명', '행정동명',
              '위도', '경도']]

c_map = folium.Map(location=[dataset['위도'].mean(), dataset['경도'].mean()], zoom_start=11)

for index, row in dataset.iterrows():
    folium.Marker(
        location=[row['위도'], row['경도']],
        popup=f"{row['상호명']} - {row['시군구명']}",
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(c_map)

c_map
c_map.save('map3.html')
